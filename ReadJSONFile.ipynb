# %% [markdown]
# # READ JSON FILE

# %%
dbutils.fs.ls("dbfs:/FileStore/tables/json_files/")
# Out:
# Out[1]: [FileInfo(path='dbfs:/FileStore/tables/json_files/purchase-1.json', name='purchase-1.json', size=2268, modificationTime=1723492450000)]

# %%
df_purchases = spark.read.option("multiline","true").json("dbfs:/FileStore/tables/json_files/purchase-1.json")

df_purchases.show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...
